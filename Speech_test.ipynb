# %%
import speech_recognition as sr

keywords = ["左", "右", "出牌", "下一個", "重開"]

def recognize_speech_from_mic(recognizer, microphone):
    if not isinstance(recognizer, sr.Recognizer):
        raise TypeError("`recognizer` must be `speech_recognition.Recognizer` instance")
    if not isinstance(microphone, sr.Microphone):
        raise TypeError("`microphone` must be `speech_recognition.Microphone` instance")

    with microphone as source:
        recognizer.adjust_for_ambient_noise(source)
        print("請開始說話...")
        audio = recognizer.listen(source)

    response = {
        "success": True,
        "error": None,
        "transcription": None
    }

    try:
        response["transcription"] = recognizer.recognize_google(audio, language='zh-TW')
    except sr.RequestError:
        response["success"] = False
        response["error"] = "API 不可用"
    except sr.UnknownValueError:
        response["error"] = "無法識別聲音"

    return response

def main():
    recognizer = sr.Recognizer()
    microphone = sr.Microphone()

    while True:
        result = recognize_speech_from_mic(recognizer, microphone)
        
        if result["transcription"]:
            print("你他媽的說了:", result["transcription"])
            for keyword in keywords:
                if keyword in result["transcription"]:
                    print(f"檢測到關鍵詞: {keyword}")
                    break
        if not result["success"]:
            break
        if result["error"]:
            print("錯誤:", result["error"])

if __name__ == "__main__":
    main()
# Out:
# 請開始說話...
# 你他媽的說了: 往左邊
# 檢測到關鍵詞: 左
# 請開始說話...
# 你他媽的說了: 往右邊
# 檢測到關鍵詞: 右
# 請開始說話...
# 錯誤: 無法識別聲音
# 請開始說話...
# 錯誤: 無法識別聲音
# 請開始說話...
# 你他媽的說了: 我要出牌
# 檢測到關鍵詞: 出牌
# 請開始說話...
# 你他媽的說了: 下一個下一個重開
# 檢測到關鍵詞: 下一個
# 請開始說話...
# 你他媽的說了: 重開
# 檢測到關鍵詞: 重開
# 請開始說話...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_74460\2988749696.py in <module>
#      49
#      50 if __name__ == "__main__":
# ---> 51     main()
#
# ~\AppData\Local\Temp\ipykernel_74460\2988749696.py in main()
#      35
#      36     while True:
# ---> 37         result = recognize_speech_from_mic(recognizer, microphone)
#      38
#      39         if result["transcription"]:
#
# ~\AppData\Local\Temp\ipykernel_74460\2988749696.py in recognize_speech_from_mic(recognizer, microphone)
#      12         recognizer.adjust_for_ambient_noise(source)
#      13         print("請開始說話...")
# ---> 14         audio = recognizer.listen(source)
#      15
#      16     response = {
#
# ~\AppData\Roaming\Python\Python39\site-packages\speech_recognition\__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     521                     break
#     522
# --> 523                 buffer = source.stream.read(source.CHUNK)
#     524                 if len(buffer) == 0: break  # reached end of the stream
#     525                 frames.append(buffer)
#
# ~\AppData\Roaming\Python\Python39\site-packages\speech_recognition\__init__.py in read(self, size)
#     197
#     198         def read(self, size):
# --> 199             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     200
#     201         def close(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\pyaudio\__init__.py in read(self, num_frames, exception_on_overflow)
#     568                 raise IOError("Not input stream",
#     569                               paCanNotReadFromAnOutputOnlyStream)
# --> 570             return pa.read_stream(self._stream, num_frames,
#     571                                   exception_on_overflow)
#     572
#
# KeyboardInterrupt:

# %%
#!/usr/bin/env python
from serial import Serial, EIGHTBITS, PARITY_NONE, STOPBITS_ONE
import speech_recognition as sr
import time

assert len(argv) == 2

s = Serial(
    port=argv[1],
    baudrate=115200,
    bytesize=EIGHTBITS,
    parity=PARITY_NONE,
    stopbits=STOPBITS_ONE,
    xonxoff=False,
    rtscts=False
)

time.sleep(2)

keywords = ["左", "右", "出牌", "下一個", "重開"]
keyword_types = {
    "左": [0,0,0,0,0,0,0,0],
    "右": [0,0,0,0,0,0,0,1],
    "出牌": [0,0,0,0,0,0,1,0],
    "下一個": [0,0,0,0,0,0,1,1],
    "重開": [0,0,0,0,0,1,0,0]
}

keywords = ["左", "右", "出牌", "下一個", "重開"]

def recognize_speech_from_mic(recognizer, microphone):
    if not isinstance(recognizer, sr.Recognizer):
        raise TypeError("`recognizer` must be `speech_recognition.Recognizer` instance")
    if not isinstance(microphone, sr.Microphone):
        raise TypeError("`microphone` must be `speech_recognition.Microphone` instance")

    with microphone as source:
        recognizer.adjust_for_ambient_noise(source)
        print("請開始說話...")
        audio = recognizer.listen(source)

    response = {
        "success": True,
        "error": None,
        "transcription": None
    }

    try:
        response["transcription"] = recognizer.recognize_google(audio, language='zh-TW')
    except sr.RequestError:
        response["success"] = False
        response["error"] = "API 不可用"
    except sr.UnknownValueError:
        response["error"] = "無法識別聲音"

    return response

def main():
    recognizer = sr.Recognizer()
    microphone = sr.Microphone()

    while True:
        result = recognize_speech_from_mic(recognizer, microphone)
        
        if result["transcription"]:
            print("你說了:", result["transcription"])
            for keyword in keywords:
                if keyword in result["transcription"]:
                    keyword_type = keyword_types[keyword]
                    print(f"檢測到keyword: {keyword}, type: {keyword_type}")
                    for i in range(8):
                        s.write(bytes([keyword_type[i]]))
                    break
        if not result["success"]:
            break
        if result["error"]:
            print("error:", result["error"])

if __name__ == "__main__":
    from sys import argv
    main()
